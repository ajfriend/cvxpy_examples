# %% [markdown]
# # Notes
#
# - Is there a way to allow for edges that have 100% detection probability?
# - need to constrain forward and backward edges to have same r value
# - general form $r \in C$ for some constraint set
# - what is bad guy's problem? max flow? shortest path? equivalence?
# - Can i recover x from complimentary slackness or optimality conditions?
# - plot the path with the unused edges colored, but faded

# %%
#%config InlineBackend.figure_format = 'pdf'
#%config InlineBackend.figure_format = 'svg'
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %% [markdown]
# # Problem statement
#
# A bad guy moves along a directed graph (cycles are allowed) with $n$ nodes and $m$ edges from node $0$ (the source) to node $n-1$ (the destination). Edge $j$ has evastion probability $p_j$, which is the probability that the bad guy moves along that edge undetected. The detection events on the edges are independent, so the probability that the bad guy makes it to the destination undetected is
# $\prod_{j \in \mathcal{P}} p_j$, where $\mathcal{P} \subset \lbrace 0,\ldots, m-1\rbrace$ is the set of edges on the bad guy's path. We assume that the bad guy knows the evasion probabilities and will take a path that maximizes the probability of making it to the destination node undetected. We let $P^\mathrm{max}$ denote this maximum probability (over paths). Note that this is a function of the edge detection failure probabilities.
#
# The evasion probability on an edge depends on the interdiction resources allocated to the edge. Here we will use a very simple model, with $r_j \in \mathbf{R}_+$ denoting the effort (say, yearly budget) allocated to edge $j$, with associated evasion probability $p_j = e^{-a_j r_j}$ , where $a_j \in \mathbf{R}_{++}$ are given. The resources will be constrained in some way such that $r \in \mathcal{C}$, where $\mathcal{C}$ represents some resource allocation constraints such as, say, a maximum for each edge or a total budget constraint.
#
# The problem is to choose resources $r \in \mathbf{R}^m$, subject to the constraints, so as to minimize $P^\mathrm{max}$.
#
# \\[
# \begin{array}{ll}
#   \mbox{minimize} & P^\mathrm{max}(r) \\
#   \mbox{subject to} & r \in \mathcal{C}
# \end{array}
# \\]
#
#
# # Bad guy's perspective
#
# To solve the problem, we first consider the bad guy's objective and formulate it as an optimization problem. Since the bad guy chooses a path only after the resources are allocated, we will drop the resource variable $r$ and consider the evasion probabilities $p$ as fixed.
#
# Let $x \in \lbrace 0,1 \rbrace^m$ be a decision variable where $x_j = 1$ denotes that the bad guy's path includes edge $j$. The $x$ variable needs to satisfy certain constraints to represent a valid path. Firstly, the number of times the path exits the source node must be exactly one more than the number of times it exits the source node. Similarly, the number of times the path enters the destination node must be exactly one more than the number of times it exits destination node. For all other nodes in the graph, the number of times the path enters and exits the node must be equal. These constraints can be represented as $Ax = b$, where
#
# \\[
# b_i = \begin{cases}
# +1 & i = 0 \\
# -1 & i = n-1\\
# 0 & \mbox{otherwise,}
# \end{cases}
# \\]
#
# \\[
# A_{ij} =
# \begin{cases}
# +1 & \mbox{if edge $j$ enters node $i$} \\
# -1 & \mbox{if edge $j$ exits node $i$} \\
# 0 & \mbox{otherwise.}
# \end{cases}
# \\]
#
# Since the bad guy's objective $\prod_{j \in \mathcal{P}} p_j$ is positive, it is equivalent for him to maximize the logarithm of the objective, which we can write as
#
# \\[
# \begin{align}
# \log\left(\prod_{j \in \mathcal{P}} p_j\right) &= \sum_{j \in \mathcal{P}} \log(p_j)\\
# &= \sum_{j=0}^{n-1} c_j x_j,
# \end{align}
# \\]
# where we've assigned $c_j = \log(p_j)$.
#
#
# The bad guy's problem can be written as
#
# \\[
# \begin{array}{ll}
#   \mbox{maximize} & c^T x \\
#   \mbox{subject to} & A x = b\\
#   & x \in \lbrace 0,1 \rbrace^m.
# \end{array}
# \\]
#
# This is a linear problem with Boolean variables, which is not convex, but we can transform it into a convex problem by relaxing the boolean constraints to get the problem
#
# \\[
# \begin{array}{ll}
#   \mbox{maximize} & c^T x \\
#   \mbox{subject to} & A x = b\\
#   & x \geq 0.
# \end{array}
# \\]
#
# It turns out that this convex problem solves the original Boolean problem *exactly*. (XXX: This is the case only when there is a unique optimal path. In the presence of multiple optimal paths, the $x^\star$ may have fractional entries, but an optimal path can still be recovered.)
#
# # Smuggler's path example
# We'll solve the smuggler's problem on an example network to see an example of an optimal path.

# %%
np.random.seed(0)

N = 10 # n = N^2 nodes
mu = .045 # node placement noise
eta = 0.12 # edge radius
n = N*N

pos = [(float(i)/N + mu*np.random.rand(), float(j)/N + mu*np.random.rand())\
       for i in range(N) for j in range(N-1,-1,-1)]
pos = dict(enumerate(pos))
G = nx.random_geometric_graph(n,eta,pos=pos)

# assign a random a_j to edge j in graph G
for i in G:
    for j in G[i]:
        if i > j:
            G[i][j]['a'] = np.random.rand()
            #G[i][j]['prob'] = np.exp(-a)
            
# create directed graph H from G, with both directions inheriting a_j from G
H = nx.DiGraph(G)
A = nx.incidence_matrix(H,oriented=True).toarray()
n,m = A.shape         
      
a = np.array([e[2]['a'] for e in H.edges_iter(data=True)])
p = np.exp(-a)

nodes = nx.draw_networkx_nodes(H,pos,node_color='w',node_size=100)
edges = nx.draw_networkx_edges(H,pos,edge_color=p,width=4,
                               edge_cmap=plt.cm.RdYlGn,arrows=False)


fig = plt.gcf()
ax = plt.gca()
fig.set_size_inches(8,6)
ax.axis([-0.02,.97,-0.02,.98])
plt.colorbar(edges)
plt.axis('off')
# Out:
# (-0.02, 0.96999999999999997, -0.02, 0.97999999999999998)

# %%
p = [e for e in H.edges_iter(data=True)]
p
# Out:
# [(0, 1, {'a': 0.3117958819941026}),
#  (0, 10, {'a': 0.4536968445560453}),
#  (1, 0, {'a': 0.3117958819941026}),
#  (1, 2, {'a': 0.6963434888154595}),
#  (1, 11, {'a': 0.5365792111087222}),
#  (2, 1, {'a': 0.6963434888154595}),
#  (2, 3, {'a': 0.3777518392924809}),
#  (2, 12, {'a': 0.9903389473967044}),
#  (3, 2, {'a': 0.3777518392924809}),
#  (3, 13, {'a': 0.6630782031001008}),
#  (4, 5, {'a': 0.1796036775596348}),
#  (4, 14, {'a': 0.02065099946572868}),
#  (4, 15, {'a': 0.7583786538361414}),
#  (5, 4, {'a': 0.1796036775596348}),
#  (5, 6, {'a': 0.02467872839133123}),
#  (5, 15, {'a': 0.32001715082246784}),
#  (6, 16, {'a': 0.5883171135536057}),
#  (6, 5, {'a': 0.02467872839133123}),
#  (7, 8, {'a': 0.06724963146324858}),
#  (7, 17, {'a': 0.8726506554473953}),
#  (8, 9, {'a': 0.6793927734985673}),
#  (8, 7, {'a': 0.06724963146324858}),
#  (9, 8, {'a': 0.6793927734985673}),
#  (9, 19, {'a': 0.7980468339125637}),
#  (10, 0, {'a': 0.4536968445560453}),
#  (10, 11, {'a': 0.8966712930403421}),
#  (10, 20, {'a': 0.9527916569719446}),
#  (11, 1, {'a': 0.5365792111087222}),
#  (11, 10, {'a': 0.8966712930403421}),
#  (11, 12, {'a': 0.21689698439847394}),
#  (11, 21, {'a': 0.6874882763878153}),
#  (12, 2, {'a': 0.9903389473967044}),
#  (12, 11, {'a': 0.21689698439847394}),
#  (12, 13, {'a': 0.26332237673715064}),
#  (13, 3, {'a': 0.6630782031001008}),
#  (13, 12, {'a': 0.26332237673715064}),
#  (13, 23, {'a': 0.7308558067701578}),
#  (14, 24, {'a': 0.25394164259502583}),
#  (14, 4, {'a': 0.02065099946572868}),
#  (14, 15, {'a': 0.38346389417189797}),
#  (15, 16, {'a': 0.8310484552361904}),
#  (15, 25, {'a': 0.025662718054531575}),
#  (15, 4, {'a': 0.7583786538361414}),
#  (15, 5, {'a': 0.32001715082246784}),
#  (15, 14, {'a': 0.38346389417189797}),
#  (16, 17, {'a': 0.6289818435911487}),
#  (16, 6, {'a': 0.5883171135536057}),
#  (16, 15, {'a': 0.8310484552361904}),
#  (17, 16, {'a': 0.6289818435911487}),
#  (17, 18, {'a': 0.27354203481563577}),
#  (17, 27, {'a': 0.42468546875150626}),
#  (17, 7, {'a': 0.8726506554473953}),
#  (18, 27, {'a': 0.37416998033422555}),
#  (18, 17, {'a': 0.27354203481563577}),
#  (18, 19, {'a': 0.1856359443059522}),
#  (18, 28, {'a': 0.5867843464581688}),
#  (19, 9, {'a': 0.7980468339125637}),
#  (19, 18, {'a': 0.1856359443059522}),
#  (19, 28, {'a': 0.8638556059232314}),
#  (19, 29, {'a': 0.11753185596203308}),
#  (20, 10, {'a': 0.9527916569719446}),
#  (20, 21, {'a': 0.21550767711355845}),
#  (20, 30, {'a': 0.1320681063451533}),
#  (21, 32, {'a': 0.565421311858509}),
#  (21, 11, {'a': 0.6874882763878153}),
#  (21, 20, {'a': 0.21550767711355845}),
#  (21, 22, {'a': 0.9473705904889242}),
#  (21, 31, {'a': 0.7168596811925937}),
#  (22, 32, {'a': 0.18327983621407862}),
#  (22, 21, {'a': 0.9473705904889242}),
#  (23, 24, {'a': 0.21331197736748198}),
#  (23, 13, {'a': 0.7308558067701578}),
#  (24, 25, {'a': 0.5182007139306632}),
#  (24, 14, {'a': 0.25394164259502583}),
#  (24, 23, {'a': 0.21331197736748198}),
#  (25, 24, {'a': 0.5182007139306632}),
#  (25, 26, {'a': 0.2074700754411094}),
#  (25, 35, {'a': 0.940431945252813}),
#  (25, 15, {'a': 0.025662718054531575}),
#  (26, 25, {'a': 0.2074700754411094}),
#  (26, 27, {'a': 0.4635754243648107}),
#  (26, 36, {'a': 0.7486636198505473}),
#  (27, 17, {'a': 0.42468546875150626}),
#  (27, 18, {'a': 0.37416998033422555}),
#  (27, 28, {'a': 0.2776287062947319}),
#  (27, 26, {'a': 0.4635754243648107}),
#  (28, 19, {'a': 0.8638556059232314}),
#  (28, 18, {'a': 0.5867843464581688}),
#  (28, 27, {'a': 0.2776287062947319}),
#  (28, 29, {'a': 0.5173791071541142}),
#  (28, 38, {'a': 0.08342243544201855}),
#  (29, 19, {'a': 0.11753185596203308}),
#  (29, 28, {'a': 0.5173791071541142}),
#  (29, 39, {'a': 0.5844760689557689}),
#  (30, 40, {'a': 0.29214752679254885}),
#  (30, 20, {'a': 0.1320681063451533}),
#  (30, 31, {'a': 0.39605970280729375}),
#  (31, 32, {'a': 0.14484775934337724}),
#  (31, 41, {'a': 0.10029394226549782}),
#  (31, 21, {'a': 0.7168596811925937}),
#  (31, 30, {'a': 0.39605970280729375}),
#  (32, 33, {'a': 0.48805628064895457}),
#  (32, 42, {'a': 0.016429629591474204}),
#  (32, 21, {'a': 0.565421311858509}),
#  (32, 22, {'a': 0.18327983621407862}),
#  (32, 31, {'a': 0.14484775934337724}),
#  (33, 32, {'a': 0.48805628064895457}),
#  (33, 34, {'a': 0.3556127378499556}),
#  (33, 43, {'a': 0.9295293167921905}),
#  (33, 44, {'a': 0.7851529120231378}),
#  (34, 33, {'a': 0.3556127378499556}),
#  (34, 35, {'a': 0.7653252538069653}),
#  (34, 44, {'a': 0.2817301057539491}),
#  (34, 45, {'a': 0.06395526612098112}),
#  (35, 25, {'a': 0.940431945252813}),
#  (35, 34, {'a': 0.7653252538069653}),
#  (35, 36, {'a': 0.9037197397459334}),
#  (35, 45, {'a': 0.4856275959346229}),
#  (35, 46, {'a': 0.8765052453165908}),
#  (36, 26, {'a': 0.7486636198505473}),
#  (36, 35, {'a': 0.9037197397459334}),
#  (36, 46, {'a': 0.33815895183684563}),
#  (37, 38, {'a': 0.5521924699224066}),
#  (37, 47, {'a': 0.2317016264712045}),
#  (38, 48, {'a': 0.9493188224156814}),
#  (38, 28, {'a': 0.08342243544201855}),
#  (38, 37, {'a': 0.5521924699224066}),
#  (38, 39, {'a': 0.961936378547229}),
#  (39, 29, {'a': 0.5844760689557689}),
#  (39, 38, {'a': 0.961936378547229}),
#  (40, 41, {'a': 0.24082877991544682}),
#  (40, 50, {'a': 0.6304479368667911}),
#  (40, 30, {'a': 0.29214752679254885}),
#  (41, 40, {'a': 0.24082877991544682}),
#  (41, 31, {'a': 0.10029394226549782}),
#  (42, 32, {'a': 0.016429629591474204}),
#  (42, 43, {'a': 0.66991654659091}),
#  (42, 52, {'a': 0.2930202845077967}),
#  (43, 33, {'a': 0.9295293167921905}),
#  (43, 42, {'a': 0.66991654659091}),
#  (43, 44, {'a': 0.5864101661863267}),
#  (43, 53, {'a': 0.6178766919175238}),
#  (43, 54, {'a': 0.34723351793221957}),
#  (44, 33, {'a': 0.7851529120231378}),
#  (44, 34, {'a': 0.2817301057539491}),
#  (44, 43, {'a': 0.5864101661863267}),
#  (44, 45, {'a': 0.9774951397444468}),
#  (44, 54, {'a': 0.14814086094816503}),
#  (45, 34, {'a': 0.06395526612098112}),
#  (45, 35, {'a': 0.4856275959346229}),
#  (45, 44, {'a': 0.9774951397444468}),
#  (45, 46, {'a': 0.9615701545414985}),
#  (45, 55, {'a': 0.47837030703998806}),
#  (46, 35, {'a': 0.8765052453165908}),
#  (46, 36, {'a': 0.33815895183684563}),
#  (46, 45, {'a': 0.9615701545414985}),
#  (47, 48, {'a': 0.9413777047064986}),
#  (47, 37, {'a': 0.2317016264712045}),
#  (48, 49, {'a': 0.7992025873523917}),
#  (48, 58, {'a': 0.3685846061296175}),
#  (48, 38, {'a': 0.9493188224156814}),
#  (48, 47, {'a': 0.9413777047064986}),
#  (49, 48, {'a': 0.7992025873523917}),
#  (49, 59, {'a': 0.8221177331942455}),
#  (50, 40, {'a': 0.6304479368667911}),
#  (50, 51, {'a': 0.874287966624947}),
#  (50, 60, {'a': 0.511318982546456}),
#  (51, 50, {'a': 0.874287966624947}),
#  (51, 52, {'a': 0.8489435553129182}),
#  (51, 61, {'a': 0.22431702897473926}),
#  (52, 42, {'a': 0.2930202845077967}),
#  (52, 51, {'a': 0.8489435553129182}),
#  (52, 53, {'a': 0.01323685775889949}),
#  (52, 62, {'a': 0.8621915174216833}),
#  (53, 43, {'a': 0.6178766919175238}),
#  (53, 52, {'a': 0.01323685775889949}),
#  (53, 54, {'a': 0.9818293898182532}),
#  (53, 63, {'a': 0.906555499221179}),
#  (54, 63, {'a': 0.7740473326986388}),
#  (54, 43, {'a': 0.34723351793221957}),
#  (54, 44, {'a': 0.14814086094816503}),
#  (54, 53, {'a': 0.9818293898182532}),
#  (54, 55, {'a': 0.4973913654986627}),
#  (55, 65, {'a': 0.40724117141380733}),
#  (55, 45, {'a': 0.47837030703998806}),
#  (55, 54, {'a': 0.4973913654986627}),
#  (56, 57, {'a': 0.6394725163987236}),
#  (56, 66, {'a': 0.23223414217094274}),
#  (57, 56, {'a': 0.6394725163987236}),
#  (57, 66, {'a': 0.13248763475798297}),
#  (57, 67, {'a': 0.7255943642105788}),
#  (57, 58, {'a': 0.13690027168559893}),
#  (58, 48, {'a': 0.3685846061296175}),
#  (58, 57, {'a': 0.13690027168559893}),
#  (58, 59, {'a': 0.18984791190275796}),
#  (58, 68, {'a': 0.7705807485027762}),
#  (59, 49, {'a': 0.8221177331942455}),
#  (59, 58, {'a': 0.18984791190275796}),
#  (59, 69, {'a': 0.07952208258675575}),
#  (60, 50, {'a': 0.511318982546456}),
#  (60, 61, {'a': 0.09784448449403405}),
#  (60, 70, {'a': 0.6720478073539145}),
#  (60, 71, {'a': 0.24536720985284477}),
#  (61, 51, {'a': 0.22431702897473926}),
#  (61, 60, {'a': 0.09784448449403405}),
#  (61, 62, {'a': 0.9729194890231303}),
#  (61, 71, {'a': 0.42053946668009845}),
#  (62, 72, {'a': 0.8605511738287938}),
#  (62, 52, {'a': 0.8621915174216833}),
#  (62, 61, {'a': 0.9729194890231303}),
#  (62, 63, {'a': 0.9608346580630002}),
#  (63, 64, {'a': 0.3331451520286419}),
#  (63, 73, {'a': 0.1314827992911276}),
#  (63, 54, {'a': 0.7740473326986388}),
#  (63, 53, {'a': 0.906555499221179}),
#  (63, 62, {'a': 0.9608346580630002}),
#  (64, 65, {'a': 0.08110138998799676}),
#  (64, 74, {'a': 0.05537432042119794}),
#  (64, 75, {'a': 0.26211814923967824}),
#  (64, 63, {'a': 0.3331451520286419}),
#  (65, 64, {'a': 0.08110138998799676}),
#  (65, 66, {'a': 0.05342718178682526}),
#  (65, 75, {'a': 0.45614056680047965}),
#  (65, 55, {'a': 0.40724117141380733}),
#  (66, 56, {'a': 0.23223414217094274}),
#  (66, 57, {'a': 0.13248763475798297}),
#  (66, 67, {'a': 0.011427458625031028}),
#  (66, 76, {'a': 0.6956254456388572}),
#  (66, 65, {'a': 0.05342718178682526}),
#  (67, 57, {'a': 0.7255943642105788}),
#  (67, 66, {'a': 0.011427458625031028}),
#  (67, 68, {'a': 0.14694664540037505}),
#  (67, 77, {'a': 0.3799269559001205}),
#  (68, 58, {'a': 0.7705807485027762}),
#  (68, 67, {'a': 0.14694664540037505}),
#  (68, 69, {'a': 0.08960303423860538}),
#  (68, 78, {'a': 0.7885455123065187}),
#  (69, 59, {'a': 0.07952208258675575}),
#  (69, 68, {'a': 0.08960303423860538}),
#  (69, 79, {'a': 0.6969972417249873}),
#  (70, 80, {'a': 0.7786953959411034}),
#  (70, 60, {'a': 0.6720478073539145}),
#  (70, 71, {'a': 0.5573687913239169}),
#  (71, 72, {'a': 0.7270442627113283}),
#  (71, 81, {'a': 0.25942256434535493}),
#  (71, 60, {'a': 0.24536720985284477}),
#  (71, 61, {'a': 0.42053946668009845}),
#  (71, 70, {'a': 0.5573687913239169}),
#  (72, 73, {'a': 0.27032790523871464}),
#  (72, 82, {'a': 0.37381313793256143}),
#  (72, 62, {'a': 0.8605511738287938}),
#  (72, 71, {'a': 0.7270442627113283}),
#  (73, 72, {'a': 0.27032790523871464}),
#  (73, 74, {'a': 0.3015986344809425}),
#  (73, 83, {'a': 0.272821902424467}),
#  (73, 63, {'a': 0.1314827992911276}),
#  (74, 64, {'a': 0.05537432042119794}),
#  (74, 73, {'a': 0.3015986344809425}),
#  (74, 83, {'a': 0.3708527992178887}),
#  (74, 75, {'a': 0.6832813355476804}),
#  (74, 84, {'a': 0.19705428018563964}),
#  (75, 64, {'a': 0.26211814923967824}),
#  (75, 65, {'a': 0.45614056680047965}),
#  (75, 74, {'a': 0.6832813355476804}),
#  (75, 76, {'a': 0.28351884658216664}),
#  (76, 66, {'a': 0.6956254456388572}),
#  (76, 75, {'a': 0.28351884658216664}),
#  (76, 77, {'a': 0.18115096173690304}),
#  (76, 86, {'a': 0.799795884570618}),
#  (77, 67, {'a': 0.3799269559001205}),
#  (77, 76, {'a': 0.18115096173690304}),
#  (77, 78, {'a': 0.0568480764332403}),
#  (78, 88, {'a': 0.3068100995451961}),
#  (78, 68, {'a': 0.7885455123065187}),
#  (78, 77, {'a': 0.0568480764332403}),
#  (79, 89, {'a': 0.9594333408334251}),
#  (79, 69, {'a': 0.6969972417249873}),
#  (80, 81, {'a': 0.7774075618487531}),
#  (80, 90, {'a': 0.6455702444560039}),
#  (80, 70, {'a': 0.7786953959411034}),
#  (81, 80, {'a': 0.7774075618487531}),
#  (81, 90, {'a': 0.03536243575549092}),
#  (81, 91, {'a': 0.43040243950806123}),
#  (81, 82, {'a': 0.587599635196389}),
#  (81, 71, {'a': 0.25942256434535493}),
#  (82, 72, {'a': 0.37381313793256143}),
#  (82, 81, {'a': 0.587599635196389}),
#  (82, 91, {'a': 0.5100168523182502}),
#  (82, 92, {'a': 0.6813925106038379}),
#  (83, 73, {'a': 0.272821902424467}),
#  (83, 74, {'a': 0.3708527992178887}),
#  (83, 84, {'a': 0.4598558837560074}),
#  (84, 74, {'a': 0.19705428018563964}),
#  (84, 83, {'a': 0.4598558837560074}),
#  (84, 85, {'a': 0.044612301254114084}),
#  (84, 94, {'a': 0.39267567654709434}),
#  (85, 96, {'a': 0.5438059500773263}),
#  (85, 84, {'a': 0.044612301254114084}),
#  (85, 86, {'a': 0.07695644698663273}),
#  (85, 95, {'a': 0.18713089175084474}),
#  (86, 96, {'a': 0.4569114216457658}),
#  (86, 76, {'a': 0.799795884570618}),
#  (86, 85, {'a': 0.07695644698663273}),
#  (86, 87, {'a': 0.518835148831526}),
#  (87, 88, {'a': 0.5775429488313755}),
#  (87, 97, {'a': 0.45860396176858587}),
#  (87, 86, {'a': 0.518835148831526}),
#  (88, 98, {'a': 0.7241676366115433}),
#  (88, 78, {'a': 0.3068100995451961}),
#  (88, 87, {'a': 0.5775429488313755}),
#  (89, 99, {'a': 0.9040443929009577}),
#  (89, 79, {'a': 0.9594333408334251}),
#  (90, 80, {'a': 0.6455702444560039}),
#  (90, 81, {'a': 0.03536243575549092}),
#  (90, 91, {'a': 0.536177494703452}),
#  (91, 81, {'a': 0.43040243950806123}),
#  (91, 82, {'a': 0.5100168523182502}),
#  (91, 92, {'a': 0.2775960977317661}),
#  (91, 90, {'a': 0.536177494703452}),
#  (92, 82, {'a': 0.6813925106038379}),
#  (92, 91, {'a': 0.2775960977317661}),
#  (92, 93, {'a': 0.1288605654663202}),
#  (93, 92, {'a': 0.1288605654663202}),
#  (93, 94, {'a': 0.9564057227959488}),
#  (94, 84, {'a': 0.39267567654709434}),
#  (94, 93, {'a': 0.9564057227959488}),
#  (94, 95, {'a': 0.903983954928237}),
#  (95, 96, {'a': 0.8820414102298896}),
#  (95, 85, {'a': 0.18713089175084474}),
#  (95, 94, {'a': 0.903983954928237}),
#  (96, 85, {'a': 0.5438059500773263}),
#  (96, 86, {'a': 0.4569114216457658}),
#  (96, 95, {'a': 0.8820414102298896}),
#  (97, 98, {'a': 0.399025321703102}),
#  (97, 87, {'a': 0.45860396176858587}),
#  (98, 88, {'a': 0.7241676366115433}),
#  (98, 97, {'a': 0.399025321703102}),
#  (98, 99, {'a': 0.6900250201912274}),
#  (99, 89, {'a': 0.9040443929009577}),
#  (99, 98, {'a': 0.6900250201912274})]

# %% [markdown]
# Taking $p_i = e^{-a_j r_j}$ is a reasonable model, forcing $c_j = -a_j r_j$ with $r_j \geq 0$.
#
# The graph is going to be a directed graph. The path will be from a source to a sink in the graph. We don't necessarily need to double the edges in the regular graph, but doing so keeps from having to choose an arbitrary orientation.
#
# The following dual has the same optimal value as the primal problem. Solving the dual allows us to minimize the best possible path for the bad guy.
#
# \\[
# \begin{array}{ll}
#   \mbox{minimize} & b^T \lambda \\
#   \mbox{subject to} & E^T \lambda \geq c
# \end{array}
# \\]
#
# The matrix $E$ is nodes by edges with a +1 for the input node and -1 for the output node.

# %%
E = nx.incidence_matrix(H,oriented=True).toarray()
plt.matshow(E)

# %%
b = np.zeros(n)
b[0] = -1
b[n-1] = 1
c = np.array([-e[2]['a'] for e in H.edges_iter(data=True)])

# %%
import cvxpy as cvx
x = cvx.Variable(m)
constr = [E*x == b,x>=0, x <= 1]
cvx.Problem(cvx.Maximize(x.T*c),constr).solve(verbose=True)
x = np.array(x.value).flatten()
# Out:
# ECOS 1.0.4 - (c) A. Domahidi, Automatic Control Laboratory, ETH Zurich, 2012-2014.
#
# It     pcost         dcost      gap     pres    dres     k/t     mu      step     IR
#  0   +8.254e+01   -4.258e+02   +5e+02   1e-02   3e-16   1e+00   8e-01    N/A     1 1 -
#  1   +5.262e+01   -3.386e+01   +9e+01   2e-03   4e-16   2e-01   1e-01   0.8518   1 1 1
#  2   +1.536e+01   -4.526e+00   +2e+01   6e-04   5e-16   4e-02   3e-02   0.8161   1 1 1
#  3   +1.048e+01   +1.654e+00   +9e+00   2e-04   7e-16   2e-02   1e-02   0.5829   1 1 1
#  4   +8.142e+00   +3.731e+00   +5e+00   1e-04   5e-16   8e-03   7e-03   0.6365   1 1 1
#  5   +6.335e+00   +5.509e+00   +9e-01   2e-05   4e-16   1e-03   1e-03   0.9899   1 1 1
#  6   +5.994e+00   +5.895e+00   +1e-01   3e-06   9e-16   1e-04   2e-04   0.8955   2 1 1
#  7   +5.946e+00   +5.945e+00   +1e-03   3e-08   4e-16   2e-06   2e-06   0.9891   2 1 1
#  8   +5.946e+00   +5.946e+00   +1e-05   3e-10   3e-16   2e-08   2e-08   0.9899   3 1 1
#  9   +5.946e+00   +5.946e+00   +1e-07   1e-11   3e-16   2e-10   2e-10   0.9899   3 2 3
#
# OPTIMAL (within feastol=1.3e-11, reltol=2.2e-08, abstol=1.3e-07).
# Runtime: 0.004474 seconds.

# %%
x.dot(c)
# Out:
# -5.9455853740431914

# %%
probs = [e[2]['prob'] for e in H.edges_iter(data=True)]
tmp = list(np.flatnonzero(x > .5))
probs = [probs[t] for t in tmp]
tmp= [H.edges()[t] for t in tmp]
nx.draw(H,with_labels=True,pos=pos,edgelist=tmp,node_size=100)

# %%
nodes = nx.draw_networkx_nodes(H,pos,node_color='w',node_size=100, with_labels=False)
edges = nx.draw_networkx_edges(H,pos,edge_color=probs,width=4,
                               edge_cmap=plt.cm.RdYlGn,edgelist=tmp,arrows=False)

fig = plt.gcf()
ax = plt.gca()
fig.set_size_inches(8,6)
ax.axis([-0.02,.97,-0.02,.98])
plt.colorbar(edges)
plt.axis('off')
# Out:
# (-0.02, 0.96999999999999997, -0.02, 0.97999999999999998)

# %%
a = np.array([e[2]['a'] for e in H.edges_iter(data=True)])
import cvxpy as cvx
nu = cvx.Variable(n)
r = cvx.Variable(m)
constr = [E.T*nu >= -cvx.mul_elemwise(a,r), r==1]#cvx.sum_entries(r) == n, r >= 0]
cvx.Problem(cvx.Minimize(nu.T*b),constr).solve(verbose=True)
nu = np.array(nu.value).flatten()
r = np.array(r.value).flatten()
# Out:
# ECOS 1.0.4 - (c) A. Domahidi, Automatic Control Laboratory, ETH Zurich, 2012-2014.
#
# It     pcost         dcost      gap     pres    dres     k/t     mu      step     IR
#  0   +5.681e-17   -8.327e-17   +2e+02   2e-01   8e+00   1e+00   5e-01    N/A     1 1 -
#  1   -1.708e+00   -1.716e+00   +3e+01   3e-02   1e+00   2e-01   8e-02   0.8481   1 1 1
#  2   -5.311e+00   -5.315e+00   +6e+00   7e-03   3e-01   3e-02   2e-02   0.8110   1 1 1
#  3   -5.572e+00   -5.576e+00   +4e+00   5e-03   2e-01   2e-02   1e-02   0.4123   1 1 1
#  4   -5.906e+00   -5.908e+00   +6e-01   7e-04   3e-02   2e-03   2e-03   0.9899   1 1 1
#  5   -5.943e+00   -5.943e+00   +5e-02   5e-05   2e-03   1e-04   1e-04   0.9519   2 1 1
#  6   -5.946e+00   -5.946e+00   +5e-04   5e-07   2e-05   1e-06   1e-06   0.9896   2 1 1
#  7   -5.946e+00   -5.946e+00   +5e-06   6e-09   2e-07   1e-08   2e-08   0.9899   3 1 1
#  8   -5.946e+00   -5.946e+00   +5e-08   6e-11   3e-09   1e-10   2e-10   0.9899   3 1 1
#
# OPTIMAL (within feastol=2.5e-09, reltol=8.8e-09, abstol=5.2e-08).
# Runtime: 0.003143 seconds.

# %%
nu.dot(b)
# Out:
# -5.9455853095732429

# %%
plt.plot(r)
